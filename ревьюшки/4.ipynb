// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic;

public abstract class Component
{
    public string Name { get; set; }
    public decimal Price { get; set; }

    public Component(string name, decimal price)
    {
        Name = name;
        Price = price;
    }

    public virtual string GetInfo()
    {
        return $"{Name} - {Price} руб.";
    }

    public string GetInfo(bool detailed)
    {
        if (detailed)
        {
            return $"{Name} Цена: {Price} руб. Детальная информация";
        }
        return GetInfo();
    }

    public string GetInfo(string category)
    {
        return $"{Name} Цена: {Price} руб. Категория: {category}";
    }
}

public interface IInstallable
{
    void Install();
}

public class CPU : Component, IInstallable
{
    public int Cores { get; set; }

    public CPU(string name, decimal price, int cores) : base(name, price)
    {
        Cores = cores;
    }


    public override string GetInfo()
    {
        return $"{base.GetInfo()} Ядра: {Cores}";
    }

    public void Install()
    {
        Console.WriteLine($"Установлен процессор: {Name}");
    }
}

public class RAM : Component, IInstallable
{
    public int Capacity { get; set; }

    public RAM(string name, decimal price, int capacity) : base(name, price)
    {
        Capacity = capacity;
    }


    public override string GetInfo()
    {
        return $"{base.GetInfo()} Объем: {Capacity}GB";
    }


    public void Install()
    {
        Console.WriteLine($"Установлена память: {Name}");
    }
}

public class GPU : Component, IInstallable
{
    public int Memory { get; set; }

    public GPU(string name, decimal price, int memory) : base(name, price)
    {
        Memory = memory;
    }


    public override string GetInfo()
    {
        return $"{base.GetInfo()} Память: {Memory}GB";
    }


    public void Install()
    {
        Console.WriteLine($"Установлена видеокарта: {Name}");
    }
}

public class HDD : Component, IInstallable
{
    public int Capacity { get; set; }

    public HDD(string name, decimal price, int capacity) : base(name, price)
    {
        Capacity = capacity;
    }


    public override string GetInfo()
    {
        return $"{base.GetInfo()} Объем: {Capacity}GB";
    }

    public void Install()
    {
        Console.WriteLine($"Установлен жесткий диск: {Name}");
    }
}


public class Computer
{
    private List<Component> components = new List<Component>();

    public void AddComponent(Component component)
    {
        components.Add(component);
        if (component is IInstallable installable)
        {
            installable.Install();
        }
    }

    public void RemoveComponent<T>(T component) where T : Component
    {
        components.Remove(component);
        Console.WriteLine($"Удален компонент: {component.Name}");
    }

    public decimal GetTotalPrice()
    {
        decimal total = 0;
        for (int i = 0; i < components.Count; i++)
        {
            total = total + components[i].Price;
        }
        return total;
    }


    public void GetTotalPrice(bool showMessage)
    {
        decimal total = GetTotalPrice();
        if (showMessage)
        {
            Console.WriteLine($"Общая стоимость: {total} руб.");
        }
    }

 
    public void ShowAllComponents()
    {
        foreach (var component in components)
        {
            Console.WriteLine(component.GetInfo());
        }
    }


    public void ShowAllComponents(bool detailed)
    {
        foreach (var component in components)
        {
            Console.WriteLine(component.GetInfo(detailed));
        }
    }
}

public static class ComputerFactory
{
    public static Computer CreateComputer(string configName, params Component[] components)
    {
        Console.WriteLine($"Создание компьютера: {configName}");
        var computer = new Computer();
        
        foreach (var component in components)
        {
            computer.AddComponent(component); 
        }
        return computer;
    }
}

  
        var cpu = new CPU("Intel i7", 25000, 8);
        var ram = new RAM("DDR4 16GB", 8000, 16);
        var gpu = new GPU("RTX 4080", 60000, 16);
        var hdd = new HDD("Seagate 2TB", 5000, 2000);

        Console.WriteLine("=== ДЕМОНСТРАЦИЯ ПЕРЕГРУЗКИ МЕТОДОВ ===");
        Console.WriteLine(cpu.GetInfo());
        Console.WriteLine(cpu.GetInfo("Процессоры"));

        Console.WriteLine("\n=== ДЕМОНСТРАЦИЯ ПОЛИМОРФИЗМА ===");
        Component[] components = { cpu, ram, gpu, hdd };
        foreach (var component in components)
        {
            Console.WriteLine(component.GetInfo());
        }

        Console.WriteLine("\n=== ДЕМОНСТРАЦИЯ GENERIC МЕТОДОВ ===");
        var computer = new Computer();
        computer.AddComponent(cpu);
        computer.AddComponent(ram);
        computer.AddComponent(gpu);

        Console.WriteLine("\n=== ДЕМОНСТРАЦИЯ ФАБРИКИ ===");
        var gamingPC = ComputerFactory.CreateComputer("Игровой ПК", cpu, ram, gpu, hdd);

        Console.WriteLine("\n=== КОМПОНЕНТЫ КОМПЬЮТЕРА ===");
        gamingPC.ShowAllComponents();
        Console.WriteLine($"Общая стоимость: {gamingPC.GetTotalPrice()} руб.");

        Console.WriteLine("\n=== ДЕТАЛЬНАЯ ИНФОРМАЦИЯ О КОМПОНЕНТАХ ===");
        gamingPC.ShowAllComponents(true);

        Console.WriteLine("\n=== ДЕМОНСТРАЦИЯ УДАЛЕНИЯ ===");
        gamingPC.RemoveComponent(gpu);
        Console.WriteLine($"Общая стоимость после удаления: {gamingPC.GetTotalPrice()} руб.");
// Out:
// === ДЕМОНСТРАЦИЯ ПЕРЕГРУЗКИ МЕТОДОВ ===
// Intel i7 - 25000 руб. Ядра: 8
// Intel i7 Цена: 25000 руб. Категория: Процессоры
//
// === ДЕМОНСТРАЦИЯ ПОЛИМОРФИЗМА ===
// Intel i7 - 25000 руб. Ядра: 8
// DDR4 16GB - 8000 руб. Объем: 16GB
// RTX 4080 - 60000 руб. Память: 16GB
// Seagate 2TB - 5000 руб. Объем: 2000GB
//
// === ДЕМОНСТРАЦИЯ GENERIC МЕТОДОВ ===
// Установлен процессор: Intel i7
// Установлена память: DDR4 16GB
// Установлена видеокарта: RTX 4080
//
// === ДЕМОНСТРАЦИЯ ФАБРИКИ ===
// Создание компьютера: Игровой ПК
// Установлен процессор: Intel i7
// Установлена память: DDR4 16GB
// Установлена видеокарта: RTX 4080
// Установлен жесткий диск: Seagate 2TB
//
// === КОМПОНЕНТЫ КОМПЬЮТЕРА ===
// Intel i7 - 25000 руб. Ядра: 8
// DDR4 16GB - 8000 руб. Объем: 16GB
// RTX 4080 - 60000 руб. Память: 16GB
// Seagate 2TB - 5000 руб. Объем: 2000GB
// Общая стоимость: 98000 руб.
//
// === ДЕТАЛЬНАЯ ИНФОРМАЦИЯ О КОМПОНЕНТАХ ===
// Intel i7 Цена: 25000 руб. Детальная информация
// ...
