// %%
public class Employee
{
    public string Name { get; set; }
    public string Position { get; set; }
    public double Salary { get; set; }

    public virtual void PrintInfo()
    {
        Console.WriteLine($"Сотрудник: {Name}, Должность: {Position}, Зарплата: {Salary}");
    }
}

public interface IReportable
{
    string GenerateReport();
}

public interface ITeamLeader
{
    string[] GetTeamMembers();
}

public class Manager : Employee
{
    public string Department { get; set; }

    public override void PrintInfo()
    {
        Console.WriteLine($"Менеджер: {Name}, Отдел: {Department}, Зарплата: {Salary}");
    }
}

public class ProjectManager : Manager, IReportable, ITeamLeader
{
    public string ProjectName { get; set; }

    public override void PrintInfo()
    {
        Console.WriteLine($"ПМ: {Name}, Проект: {ProjectName}, Зарплата: {Salary}");
    }

    public string GenerateReport()
    {
        return $"Отчет по проекту {ProjectName}";
    }

    public string[] GetTeamMembers()
    {
        return new string[] { "Анна", "Борис", "Виктор" };
    }
}

Employee emp = new Employee { Name = "Иван", Position = "Разработчик", Salary = 50000 };
Manager mgr = new Manager { Name = "Мария", Department = "IT", Salary = 70000 };
ProjectManager pm = new ProjectManager { Name = "Алексей", ProjectName = "Новый сайт", Salary = 90000 };

emp.PrintInfo();
mgr.PrintInfo();
pm.PrintInfo();

Console.WriteLine(pm.GenerateReport());
Console.WriteLine("Команда: " + string.Join(", ", pm.GetTeamMembers()));
// Out:
// Сотрудник: Иван, Должность: Разработчик, Зарплата: 50000
// Менеджер: Мария, Отдел: IT, Зарплата: 70000
// ПМ: Алексей, Проект: Новый сайт, Зарплата: 90000
// Отчет по проекту Новый сайт
// Команда: Анна, Борис, Виктор
