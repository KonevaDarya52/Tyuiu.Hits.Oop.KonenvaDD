// %%
public class Product
{
    private string Name { get; set; }
    private decimal Price { get; set; }
    private int Quantity { get; set; }
    protected string Category { get; set; }
    internal string Description { get; set; }

    public Product(string name, decimal price, int quantity, string category, string description)
    {
        Name = name;
        Price = price;
        Quantity = quantity;
        Category = category;
        Description = description;
    }

    public decimal GetTotalPrice()
    {
        return Price * Quantity;
    }

    public void UpdateQuantity(int amount)
    {
        Quantity += amount;
    }

    public string GetProductInfo()
    {
        return $"Товар: {Name}\nЦена: {Price} руб.\nКоличество в наличии: {Quantity}\nКатегория: {Category}\nОписание: {Description}";
    }
}

public class Seller
{
    private string Name { get; set; }
    private string EmployedId { get; set; }
    protected decimal Salary { get; set; }
    internal string ContactInfo { get; set; }

    public Seller(string name, string employedId, decimal salary, string contactInfo)
    {
        Name = name;
        EmployedId = employedId;
        Salary = salary;
        ContactInfo = contactInfo;
    }

    public void AddProduct(Product product)
    {}

    public void SellProduct(Product product, int quantity)
    {
        product.UpdateQuantity(-quantity);
        Console.WriteLine($"Продано {quantity} единиц товара");
    }

    public string GetSellerInfo()
    {
        return $"Продавец: {Name}\nID: {EmployedId}\nЗарплата: {Salary} руб.\nКонтакты: {ContactInfo}";
    }
}

public class Store
{
    private string StoreName { get; set; }
    private string Location { get; set; }
    public string StoreHours { get; set; }

    public Store(string storeName, string location, string storeHours)
    {
        StoreName = storeName;
        Location = location;
        StoreHours = storeHours;
    }

    public void AddSeller(Seller seller)
    {}

    public void ListProducts()
    {}

    public string GetStoreInfo()
    {
        return $"Магазин: {StoreName}\nАдрес: {Location}\nЧасы работы: {StoreHours}";
    }
}
        Console.WriteLine("=== МАГАЗИН ===\n");

        Product laptop = new Product("Ноутбук", 50000, 10, "Электроника", "Игровой ноутбук");

        Seller seller1 = new Seller("Иван Иванов", "EMP001", 40000, "ivan@store.com");

        Store myStore = new Store("ТехноМир", "ул. Центральная, 1", "9:00-21:00");

        seller1.AddProduct(laptop);
        myStore.AddSeller(seller1);

        Console.WriteLine("ИНФОРМАЦИЯ О МАГАЗИНЕ:");
        Console.WriteLine(myStore.GetStoreInfo());

        Console.WriteLine("\nИНФОРМАЦИЯ О ПРОДАВЦАХ:");
        Console.WriteLine(seller1.GetSellerInfo());

        Console.WriteLine("\nИНФОРМАЦИЯ О ТОВАРАХ:");
        Console.WriteLine(laptop.GetProductInfo());

        Console.WriteLine("\nПРОДАЖА ТОВАРОВ:");
        Console.WriteLine("Продаем 2 ноутбука:");
        seller1.SellProduct(laptop, 2);
        Console.WriteLine(laptop.GetProductInfo());

        Console.WriteLine("\nОБЩАЯ СТОИМОСТЬ ОСТАВШИХСЯ ТОВАРОВ:");
        Console.WriteLine($"Ноутбуки: {laptop.GetTotalPrice()} руб.");
// Out:
// === МАГАЗИН ===
//
// ИНФОРМАЦИЯ О МАГАЗИНЕ:
// Магазин: ТехноМир
// Адрес: ул. Центральная, 1
// Часы работы: 9:00-21:00
//
// ИНФОРМАЦИЯ О ПРОДАВЦАХ:
// Продавец: Иван Иванов
// ID: EMP001
// Зарплата: 40000 руб.
// Контакты: ivan@store.com
//
// ИНФОРМАЦИЯ О ТОВАРАХ:
// Товар: Ноутбук
// Цена: 50000 руб.
// Количество в наличии: 10
// Категория: Электроника
// Описание: Игровой ноутбук
//
// ПРОДАЖА ТОВАРОВ:
// Продаем 2 ноутбука:
// Продано 2 единиц товара
// Товар: Ноутбук
// Цена: 50000 руб.
// Количество в наличии: 8
// Категория: Электроника
// Описание: Игровой ноутбук
//
// ОБЩАЯ СТОИМОСТЬ ОСТАВШИХСЯ ТОВАРОВ:
// Ноутбуки: 400000 руб.
